# %%
import pandas as pd 
import numpy as np
import random
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score, precision_score, classification_report, confusion_matrix, f1_score, recall_score 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
p = 0.15

# %%
print('Initiating Processing')

DNS = (pd.read_csv('E:/FYP-dataset/train_dataset/DrDoS_DNS.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 1/11')

LDAP = (pd.reshapesv('E:/FYP-dataset/train_dataset/DrDoS_LDAP.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 2/11')

MSSQL = (pd.read_csv('E:/FYP-dataset/train_dataset/DrDoS_MSSQL.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 3/11')

NetBIOS = (pd.read_csv('E:/FYP-dataset/train_dataset/DrDoS_NetBIOS.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 4/11')

NTP = (pd.read_csv('E:/FYP-dataset/train_dataset/DrDoS_NTP.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 5/11')

SNMP = (pd.read_csv('E:/FYP-dataset/train_dataset/DrDoS_SNMP.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 6/11')

SSDP = (pd.read_csv('E:/FYP-dataset/train_dataset/DrDoS_SSDP.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 7/11')

UDP = (pd.read_csv('E:/FYP-dataset/train_dataset/DrDoS_UDP.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 8/11')

Syn = (pd.read_csv('E:/FYP-dataset/train_dataset/Syn.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 9/11')

UDPLag = (pd.read_csv('E:/FYP-dataset/train_dataset/UDPLag.csv')[lambda i:i[" Label"]=="BENIGN"])
print('Processed 10/11')

# TFTP = (pd.read_csv('E:/FYP-dataset/train_dataset/TFTP.csv')[lambda i:i[" Label"]=="BENIGN"])
# print('Processed 11/11')

print('Finished Processing')
# Out:
# Initiating Processing
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2148/1132204187.py in <module>
#       1 print('Initiating Processing')
#       2
# ----> 3 DNS = (pd.read_csv('E:/FYP-dataset/train_dataset/DrDoS_DNS.csv')[lambda i:i[" Label"]=="BENIGN"])
#       4 print('Processed 1/11')
#       5
#
# c:\users\user\envs\test\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\users\user\envs\test\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\users\user\envs\test\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# c:\users\user\envs\test\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# c:\users\user\envs\test\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# c:\users\user\envs\test\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# c:\users\user\envs\test\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# c:\users\user\envs\test\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# c:\users\user\envs\test\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# c:\users\user\envs\test\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# c:\users\user\envs\test\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers._try_int64()
#
# MemoryError: Unable to allocate 64.0 KiB for an array with shape (8192,) and data type int64

# %%
benign_data = pd.concat([DNS, LDAP, MSSQL, NetBIOS, NTP, SNMP, SSDP, UDP, Syn, UDPLag, TFTP], ignore_index = True)
benign_data = benign_data.sample(frac=1)
benign_data.shape
# Out:
# (81616, 88)

# %%
data[' Label'].value_counts()
# Out:
# Syn              49990
# DrDoS_SSDP       49987
# DrDoS_SNMP       49986
# DrDoS_MSSQL      49975
# DrDoS_NetBIOS    49973
# DrDoS_UDP        49969
# DrDoS_DNS        49968
# DrDoS_LDAP       49960
# TFTP             49934
# UDP-lag          49434
# DrDoS_NTP        49418
# BENIGN            1354
# WebDDoS             52
# Name:  Label, dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Flow ID', ' Source IP', ' Source Port',
#        ' Destination IP', ' Destination Port', ' Protocol', ' Timestamp',
#        ' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
#        ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length',
#        ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance',
#        'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count',
#        ' PSH Flag Count', ' ACK Flag Count', ' URG Flag Count',
#        ' CWE Flag Count', ' ECE Flag Count', ' Down/Up Ratio',
#        ' Average Packet Size', ' Avg Fwd Segment Size',
#        ' Avg Bwd Segment Size', ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk',
#        ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk',
#        ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets',
#        ' Subflow Fwd Bytes', ' Subflow Bwd Packets', ' Subflow Bwd Bytes',
#        'Init_Win_bytes_forward', ' Init_Win_bytes_backward',
#        ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean',
#        ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std',
#        ' Idle Max', ' Idle Min', 'SimillarHTTP', ' Inbound', ' Label'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 0','Init_Win_bytes_forward', ' Init_Win_bytes_backward',
       ' act_data_pkt_fwd', ' min_seg_size_forward'], axis = 1)

# %%
data_real = data.replace(np.inf, np.nan)
df = data_real.dropna(axis=0)
df
# Out:
#                                        Flow ID   Source IP   Source Port  \
# 501983  172.16.0.5-192.168.50.1-63044-58113-17  172.16.0.5         63044
# 239648   172.16.0.5-192.168.50.1-1006-65482-17  172.16.0.5          1006
# 523254    172.16.0.5-192.168.50.1-62486-651-17  172.16.0.5         62486
# 306150  172.16.0.5-192.168.50.1-53147-60252-17  172.16.0.5         53147
# 497974     172.16.0.5-192.168.50.1-7111-7111-6  172.16.0.5          7111
# ...                                        ...         ...           ...
# 459839   172.16.0.5-192.168.50.1-40710-40710-6  172.16.0.5         40710
# 370078   172.16.0.5-192.168.50.1-51075-5636-17  172.16.0.5         51075
# 26222     172.16.0.5-192.168.50.1-999-57257-17  172.16.0.5           999
# 333141  172.16.0.5-192.168.50.1-55420-60126-17  172.16.0.5         55420
# 348989  172.16.0.5-192.168.50.1-46926-42476-17  172.16.0.5         46926
#
#         Destination IP   Destination Port   Protocol  \
# 501983    192.168.50.1              58113         17
# 239648    192.168.50.1              65482         17
# 523254    192.168.50.1                651         17
# 306150    192.168.50.1              60252         17
# 497974    192.168.50.1               7111          6
# ...                ...                ...        ...
# 459839    192.168.50.1              40710          6
# 370078    192.168.50.1               5636         17
# 26222     192.168.50.1              57257         17
# 333141    192.168.50.1              60126         17
# 348989    192.168.50.1              42476         17
#
#                          Timestamp   Flow Duration   Total Fwd Packets  \
# 501983  2018-12-01 13:52:16.955513               2                   2
# 239648  2018-12-01 10:39:59.980386             548                  86
# 523254  2018-12-01 13:51:53.269704         2999631                   4
# 306150  2018-12-01 12:28:00.720018               1                   2
# 497974  2018-12-01 13:29:43.861721        40196502                  10
# ...                            ...             ...                 ...
# 459839  2018-12-01 13:29:53.585432        23966379                   6
# 370078  2018-12-01 13:01:33.616173               1                   2
# 26222   2018-12-01 11:10:05.528876              48                   2
# 333141  2018-12-01 12:30:36.437100              49                   2
# 348989  2018-12-01 12:27:56.306417          108002                   4
#
#          Total Backward Packets  ...   Active Std   Active Max   Active Min  \
# 501983                        0  ...     0.000000          0.0          0.0
# 239648                        0  ...     0.000000          0.0          0.0
# 523254                        0  ...     0.000000          0.0          0.0
# 306150                        0  ...     0.000000          0.0          0.0
# 497974                        0  ...    24.837807         51.0          1.0
# ...                         ...  ...          ...          ...          ...
# 459839                        4  ...    12.020815        101.0         84.0
# 370078                        0  ...     0.000000          0.0          0.0
# 26222                         0  ...     0.000000          0.0          0.0
# 333141                        0  ...     0.000000          0.0          0.0
# 348989                        0  ...     0.000000          0.0          0.0
#
#          Idle Mean      Idle Std    Idle Max   Idle Min  SimillarHTTP  \
# 501983         0.0  0.000000e+00         0.0        0.0             0
# 239648         0.0  0.000000e+00         0.0        0.0             0
# 523254         0.0  0.000000e+00         0.0        0.0             0
# 306150         0.0  0.000000e+00         0.0        0.0             0
# 497974  10049111.5  2.728815e+06  11999395.0  6006111.0             0
# ...            ...           ...         ...        ...           ...
# 459839  11983096.5  8.404212e+06  17925772.0  6040421.0             0
# 370078         0.0  0.000000e+00         0.0        0.0             0
# 26222          0.0  0.000000e+00         0.0        0.0             0
# 333141         0.0  0.000000e+00         0.0        0.0             0
# 348989         0.0  0.000000e+00         0.0        0.0             0
#
#          Inbound       Label
# 501983         1        TFTP
# 239648         1   DrDoS_NTP
# 523254         1        TFTP
# 306150         1  DrDoS_SSDP
# 497974         1     UDP-lag
# ...          ...         ...
# 459839         1     UDP-lag
# 370078         1   DrDoS_UDP
# 26222          1   DrDoS_DNS
# 333141         1  DrDoS_SSDP
# 348989         1  DrDoS_SSDP
#
# [530045 rows x 83 columns]

# %%
df_x = df.drop([' Label', 'SimillarHTTP',' Timestamp'], axis = 1)

# %%
df_y = df[' Label']
df_y.unique()
# Out:
# array(['TFTP', 'DrDoS_NTP', 'DrDoS_SSDP', 'UDP-lag', 'DrDoS_DNS', 'Syn',
#        'DrDoS_SNMP', 'DrDoS_NetBIOS', 'DrDoS_UDP', 'DrDoS_LDAP',
#        'DrDoS_MSSQL', 'BENIGN', 'WebDDoS'], dtype=object)

# %% [markdown]
# ### LABEL ENCODING

# %%
new = []
for i in df_y:
    if i == 'BENIGN':
        new.append(0)
    else:
        new.append(1)
df_y[df_y["Label"]==1].value_counts()
# le = LabelEncoder()
# y_train = le.fit_transform(new)

# %%
le_fid = LabelEncoder()
le_fid.fit(df_x['Flow ID'])
df_x['Flow ID'] = le_fid.fit_transform(df_x['Flow ID'])

le_sip = LabelEncoder()
le_sip.fit(df_x[' Source IP'])
df_x[' Source IP'] = le_sip.fit_transform(df_x[' Source IP'])

le_dip = LabelEncoder()
le_dip.fit(df_x[' Destination IP'])
df_x[' Destination IP'] = le_dip.fit_transform(df_x[' Destination IP'])

# %% [markdown]
# ### FEATURE SELECTION

# %%
model = ExtraTreesClassifier(random_state=42)
model.fit(df_x, y_train)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
model.feature_importances_
# Out:
# array([4.30542785e-02, 1.85143659e-01, 1.91623114e-02, 1.31414156e-01,
#        1.78343355e-02, 9.95153805e-03, 1.13358953e-03, 7.18235134e-04,
#        3.36553647e-03, 1.47967910e-03, 1.57408937e-03, 2.81924929e-03,
#        2.62799674e-03, 2.64489786e-03, 2.90201922e-03, 1.05973971e-02,
#        3.23717830e-03, 2.37729591e-02, 7.34161121e-03, 2.41351162e-03,
#        2.96124229e-03, 6.25453975e-04, 6.55843785e-04, 8.59385373e-04,
#        1.22114650e-03, 8.47985668e-04, 4.99913595e-04, 5.63041841e-04,
#        3.24219039e-04, 4.71783063e-04, 1.13766533e-03, 2.36365060e-04,
#        4.01034971e-04, 5.63934483e-04, 3.21014983e-04, 2.20220529e-02,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.83882712e-03,
#        2.86889621e-03, 4.86530304e-03, 1.15590440e-03, 9.99038015e-03,
#        7.21368668e-03, 4.48781647e-03, 5.52249206e-03, 3.46386411e-03,
#        0.00000000e+00, 2.21713979e-04, 2.38269466e-02, 0.00000000e+00,
#        8.05756897e-03, 7.84291714e-02, 3.07336847e-02, 0.00000000e+00,
#        1.18924017e-02, 5.16984738e-03, 6.06925209e-03, 2.29968143e-02,
#        1.89269921e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.45690485e-04,
#        7.48186275e-04, 3.63322102e-03, 4.71210408e-03, 4.88067469e-04,
#        1.57499451e-04, 3.48719753e-04, 9.57994564e-04, 7.80842047e-04,
#        4.13778546e-05, 6.60322503e-04, 3.74819758e-04, 2.46953573e-01])

# %%
feature_importance_std = pd.Series(model.feature_importances_, index=df_x.columns)
feature_importance_std.nlargest(15).plot(kind='bar', title='Standardised Dataset Feature Selection using ExtraTreesClassifier')
# Out:
# <AxesSubplot:title={'center':'Standardised Dataset Feature Selection using ExtraTreesClassifier'}>

# %%
ft = feature_importance_std.nlargest(15).to_dict().keys()

# %%
x_train = df_x[ft]

# %%
x_train
# Out:
#          Inbound   Source IP   Destination IP   URG Flag Count  Flow ID  \
# 501983         1           5               86                0   322800
# 239648         1           5               86                0     2970
# 523254         1           5               86                0   297029
# 306150         1           5               86                0   182638
# 497974         1           5               86                0   393085
# ...          ...         ...              ...              ...      ...
# 459839         1           5               86                0   102484
# 370078         1           5               86                0   162319
# 26222          1           5               86                0   524914
# 333141         1           5               86                0   205717
# 348989         1           5               86                0   138249
#
#          CWE Flag Count   RST Flag Count   Bwd Packet Length Mean  \
# 501983                0                0                      0.0
# 239648                0                0                      0.0
# 523254                0                0                      0.0
# 306150                0                0                      0.0
# 497974                0                0                      0.0
# ...                 ...              ...                      ...
# 459839                0                0                      0.0
# 370078                0                0                      0.0
# 26222                 0                0                      0.0
# 333141                0                0                      0.0
# 348989                0                0                      0.0
#
#          Avg Bwd Segment Size  Fwd PSH Flags   Source Port   Destination Port  \
# 501983                    0.0              0         63044              58113
# 239648                    0.0              0          1006              65482
# 523254                    0.0              0         62486                651
# 306150                    0.0              0         53147              60252
# 497974                    0.0              0          7111               7111
# ...                       ...            ...           ...                ...
# 459839                    0.0              0         40710              40710
# 370078                    0.0              0         51075               5636
# 26222                     0.0              0           999              57257
# 333141                    0.0              0         55420              60126
# 348989                    0.0              0         46926              42476
#
#          Down/Up Ratio  Bwd Packet Length Max   Min Packet Length
# 501983             0.0                    0.0               516.0
# 239648             0.0                    0.0               224.0
# 523254             0.0                    0.0               516.0
# 306150             0.0                    0.0               373.0
# 497974             0.0                    0.0                 0.0
# ...                ...                    ...                 ...
# 459839             0.0                    0.0                 0.0
# 370078             0.0                    0.0               401.0
# 26222              0.0                    0.0              1272.0
# 333141             0.0                    0.0               462.0
# 348989             0.0                    0.0               330.0
#
# [530045 rows x 15 columns]

# %% [markdown]
# ### TEST DATA PREPROCESSING

# %%
p = 0.25
print('Initiating Processing')

test_LDAP = pd.read_csv('E:/FYP-dataset/test_dataset/LDAP.csv',header=0, 
         skiprows=lambda i: i>0 and random.random() > p)
test_LDAP = test_LDAP.sample(n=20000,random_state=42)
print('Processed 1/7')

test_MSSQL = pd.read_csv('E:/FYP-dataset/test_dataset/MSSQL.csv',header=0, 
         skiprows=lambda i: i>0 and random.random() > p)
test_MSSQL = test_MSSQL.sample(n=20000,random_state=42)
print('Processed 2/7')

test_NetBIOS = pd.read_csv('E:/FYP-dataset/test_dataset/NetBIOS.csv',header=0, 
         skiprows=lambda i: i>0 and random.random() > p)
test_NetBIOS = test_NetBIOS.sample(n=20000,random_state=42)
print('Processed 3/7')

test_UDP = pd.read_csv('E:/FYP-dataset/test_dataset/UDP.csv',header=0, 
         skiprows=lambda i: i>0 and random.random() > p)
test_UDP = test_UDP.sample(n=20000,random_state=42)
print('Processed 4/7')

test_Syn = pd.read_csv('E:/FYP-dataset/test_dataset/Syn.csv',header=0, 
         skiprows=lambda i: i>0 and random.random() > p)
test_Syn = test_Syn.sample(n=20000,random_state=42)
print('Processed 5/7')

test_UDPLag = pd.read_csv('E:/FYP-dataset/test_dataset/UDPLag.csv',header=0, 
         skiprows=lambda i: i>0 and random.random() > p)
test_UDPLag = test_UDPLag.sample(n=20000,random_state=42)
print('Processed 6/7')

test_Portmap = pd.read_csv('E:/FYP-dataset/test_dataset/Portmap.csv',header=0, 
         skiprows=lambda i: i>0 and random.random() > p)
test_Portmap = test_Portmap.sample(n=20000,random_state=42)
print('Processed 7/7')

print('Finished Processing')
# Out:
# Initiating Processing
# Processed 1/7
# Processed 2/7
# Processed 3/7
# Processed 4/7
# Processed 5/7
# Processed 6/7
# Processed 7/7
# Finished Processing

# %%
df_test = pd.concat([test_LDAP, test_MSSQL, test_NetBIOS, test_UDP, test_Syn, test_UDPLag, test_Portmap], ignore_index = True)
df_test = df_test.sample(frac=1)

# %%
df_test = df_test.replace(np.inf, np.nan)
df_test = df_test.dropna(axis=0)
df_test_x = df_test[ft]
df_test_y = df_test[' Label']

# %%
la = []
for i in df_test_y:
    if i == 'BENIGN':
        la.append(0)
    else:
        la.append(1)
le2 = LabelEncoder()
y_test = le2.fit_transform(la)

# %%
le_fidt = LabelEncoder()
le_fidt.fit(df_test_x['Flow ID'])
df_test_x['Flow ID'] = le_fidt.fit_transform(df_test_x['Flow ID'])

le_sipt = LabelEncoder()
le_sipt.fit(df_test_x[' Source IP'])
df_test_x[' Source IP'] = le_sipt.fit_transform(df_test_x[' Source IP'])

le_dipt = LabelEncoder()
le_dipt.fit(df_test_x[' Destination IP'])
df_test_x[' Destination IP'] = le_dipt.fit_transform(df_test_x[' Destination IP'])

# %% [markdown]
# ### STANDARDIZATION

# %%
ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.fit_transform(df_test_x)

# %%
x_train.shape
# Out:
# (530045, 15)

# %%
y_train.shape
# Out:
# (530045,)

# %%
x_test.shape
# Out:
# (133888, 15)

# %%
y_test.shape
# Out:
# (133888,)

# %% [markdown]
# ### RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_y_pred = rf.predict(x_test)

# %%
print('Accuracy: ')
print(accuracy_score(y_test, rf_y_pred))
print('Precison: ')
print(precision_score(y_test, rf_y_pred))
print('Recall: ')
print(recall_score(y_test, rf_y_pred))
print('F1: ')
print(f1_score(y_test, rf_y_pred))

print("\nClassification Report for Random Forest: \n", classification_report(le2.inverse_transform(y_test), le2.inverse_transform(rf_y_pred)))
# Out:
# Accuracy:
# 0.9989920784834887
# Precison:
# 0.9989867375199838
# Recall:
# 1.0
# F1:
# 0.999493111954673
#
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91       841
#            1       1.00      1.00      1.00    133098
#
#     accuracy                           1.00    133939
#    macro avg       1.00      0.92      0.96    133939
# weighted avg       1.00      1.00      1.00    133939

# %%
cf_matrix_rf = confusion_matrix(y_test, rf_y_pred)

# %%
ax = sns.heatmap(cf_matrix_rf, annot=True, cmap='Blues', fmt='g')

ax.set_title('Confusion Matrix');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

binary = ['Benign','Malicious']

ax.xaxis.set_ticklabels(binary)
ax.yaxis.set_ticklabels(binary)

plt.show()

# %% [markdown]
# ### DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier 
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_y_pred = dt.predict(x_test)

# %%
print('Accuracy: ')
print(accuracy_score(y_test, dt_y_pred))
print('Precision: ')
print(precision_score(y_test, dt_y_pred))
print('Recall: ')
print(recall_score(y_test, dt_y_pred))
print('F1: ')
print(f1_score(y_test, dt_y_pred))

print("\nClassification Report for Decision Tree: \n", classification_report(le2.inverse_transform(y_test), le2.inverse_transform(dt_y_pred)))
# Out:
# Accuracy:
# 0.9961176356401048
# Precision:
# 0.9961083087607957
# Recall:
# 1.0
# F1:
# 0.9980503606832737
#
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       1.00      0.38      0.55       841
#            1       1.00      1.00      1.00    133098
#
#     accuracy                           1.00    133939
#    macro avg       1.00      0.69      0.78    133939
# weighted avg       1.00      1.00      1.00    133939

# %%
cf_matrix_dt = confusion_matrix(y_test, dt_y_pred)

# %%
ax = sns.heatmap(cf_matrix_dt, annot=True, cmap='Blues', fmt='g')

ax.set_title('Confusion Matrix');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

ax.xaxis.set_ticklabels(binary)
ax.yaxis.set_ticklabels(binary)

plt.show()

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3,n_jobs=-1)
neigh.fit(x_train, y_train) 
knn_y_pred = neigh.predict(x_test)

# %%
print('Accuracy: ')
print(accuracy_score(y_test, knn_y_pred))
print('Precision: ')
print(precision_score(y_test, knn_y_pred))
print('Recall: ')
print(recall_score(y_test, knn_y_pred))
print('F1: ')
print(f1_score(y_test, knn_y_pred))

print("\nClassification Report for KNN: \n", classification_report(le2.inverse_transform(y_test), le2.inverse_transform(knn_y_pred)))
# Out:
# Accuracy:
# 0.9997237548436229
# Precision:
# 0.9997896587212752
# Recall:
# 0.9999323806518505
# F1:
# 0.9998610145934675
#
# Classification Report for KNN:
#                precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       841
#            1       1.00      1.00      1.00    133098
#
#     accuracy                           1.00    133939
#    macro avg       0.99      0.98      0.99    133939
# weighted avg       1.00      1.00      1.00    133939

# %%
cf_matrix_knn = confusion_matrix(y_test, knn_y_pred)

# %%
ax = sns.heatmap(cf_matrix_knn, annot=True, cmap='Blues', fmt='g')

ax.set_title('Confusion Matrix');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

ax.xaxis.set_ticklabels(binary)
ax.yaxis.set_ticklabels(binary)

plt.show()

# %% [markdown]
# ### ANN

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout

# %%
from sklearn.model_selection import train_test_split
x_train_ann, x_val, y_train_ann, y_val = train_test_split(x_train, y_train, test_size = 0.20, random_state = 42)

# %%
model = Sequential()
model.add(Dense(8, input_dim=len(ft), activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 128
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dropout_1 (Dropout)         (None, 4)                 0
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 169
# Trainable params: 169
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
num_batch = 1000
num_epochs = 40
model.fit(x_train_ann, y_train_ann, batch_size=num_batch, validation_data=[x_val, y_val], epochs = num_epochs, verbose=1)
# model.save('./binary/model_weights')

model.save("binary_classifier.h5")
# Out:
# Epoch 1/40
# 425/425 [==============================] - 2s 3ms/step - loss: 0.2697 - accuracy: 0.9688 - val_loss: 0.0250 - val_accuracy: 0.99970s - loss: 0.3923 -
# Epoch 2/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0530 - accuracy: 0.9988 - val_loss: 0.0025 - val_accuracy: 0.9998: 0s - loss: 0.0665  - ETA: 0s - loss: 0.0539 - accuracy: 0.
# Epoch 3/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0323 - accuracy: 0.9989 - val_loss: 9.1320e-04 - val_accuracy: 0.9999
# Epoch 4/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0259 - accuracy: 0.9989 - val_loss: 6.2839e-04 - val_accuracy: 0.9999oss: 0.0268 - accu
# Epoch 5/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0184 - accuracy: 0.9990 - val_loss: 5.0891e-04 - val_accuracy: 0.9999 loss: 0.0214 - accuracy: 0.99 - ETA: 0s - loss: 0.0210 - ac
# Epoch 6/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0088 - accuracy: 0.9989 - val_loss: 5.2052e-04 - val_accuracy: 0.9999.0089 - accuracy: 0.
# Epoch 7/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0069 - accuracy: 0.9990 - val_loss: 4.3259e-04 - val_accuracy: 0.9999s: 0.0071 - accuracy - ETA: 0s - loss: 0.0071 - accuracy:
# Epoch 8/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 4.2714e-04 - val_accuracy: 0.9999s: 0.0062 - accuracy
# Epoch 9/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 3.7897e-04 - val_accuracy: 0.9999.0054 - accu
# Epoch 10/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 3.7999e-04 - val_accuracy: 0.9999
# Epoch 11/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 3.5606e-04 - val_accuracy: 0.9999 0.0049 - accura - ETA: 0s - loss: 0.0050 - accu
# Epoch 12/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 2.7845e-04 - val_accuracy: 0.9999047 - accu - ETA: 0s - loss: 0.0047 - accuracy: 0.99
# Epoch 13/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 2.8537e-04 - val_accuracy: 0.99997 - accuracy:
# Epoch 14/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 2.7880e-04 - val_accuracy: 0.9999: 0.
# Epoch 15/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 2.6150e-04 - val_accuracy: 0.9999oss: 0.0044 - accuracy: 0. - ETA: 0s - loss: 0.0043 - ac
# Epoch 16/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 2.6480e-04 - val_accuracy: 0.99991 - accuracy: 0.99
# Epoch 17/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 2.4704e-04 - val_accuracy: 0.9999
# Epoch 18/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 2.2864e-04 - val_accuracy: 0.9999 loss: 0.0040 - accura
# Epoch 19/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 2.3079e-04 - val_accuracy: 0.9999
# Epoch 20/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 1.7940e-04 - val_accuracy: 1.0000
# Epoch 21/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 2.0820e-04 - val_accuracy: 0.9999 0.0035 - accuracy - ETA: 0s - loss: 0.0034 - accuracy:  - ETA: 0s - loss: 0.0035 - accuracy
# Epoch 22/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 1.6986e-04 - val_accuracy: 0.9999
# Epoch 23/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 1.7764e-04 - val_accuracy: 0.9999 - loss: 0.0034 -
# Epoch 24/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 1.4248e-04 - val_accuracy: 0.9999s: 0.0034 - accuracy: 0.99
# Epoch 25/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 1.1226e-04 - val_accuracy: 1.0000.0035 - ac
# Epoch 26/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.0824e-04 - val_accuracy: 1.0000
# Epoch 27/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 1.4868e-04 - val_accuracy: 0.9999
# Epoch 28/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 9.7396e-05 - val_accuracy: 1.0000
# Epoch 29/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 1.5416e-04 - val_accuracy: 0.9999
# Epoch 30/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 1.1680e-04 - val_accuracy: 0.9999 - loss: 0.0
# Epoch 31/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 1.0473e-04 - val_accuracy: 1.0000oss: 0.0031 -
# Epoch 32/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 1.2004e-04 - val_accuracy: 0.9999
# Epoch 33/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.2160e-04 - val_accuracy: 1.0000
# Epoch 34/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 1.0164e-04 - val_accuracy: 1.0000 0.0033 - accuracy: 0. - ETA: 0s - loss: 0.0032 - accuracy:
# Epoch 35/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.0371e-04 - val_accuracy: 1.0000 loss: 0.0033 -  - ETA: 0s - loss: 0.0032 - accuracy:
# Epoch 36/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 1.1285e-04 - val_accuracy: 1.0000
# Epoch 37/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 9.9697e-05 - val_accuracy: 1.0000
# Epoch 38/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.2470e-04 - val_accuracy: 1.0000 - loss: 0.0032 - accura - ETA: 0s - loss: 0.0031 - accuracy: 0.99 - ETA: 0s - loss: 0.0031 - accuracy:  - ETA: 0s - loss: 0.0031 - accuracy: 0.
# Epoch 39/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 9.1958e-05 - val_accuracy: 1.00001 - accuracy:
# Epoch 40/40
# 425/425 [==============================] - 1s 2ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 9.4417e-05 - val_accuracy: 1.0000

# %%
loaded_model = load_model("binary_classifier.h5")

print(loaded_model.evaluate(x_test,y_test))
# Out:
# 4184/4184 [==============================] - 5s 1ms/step - loss: 0.0016 - accuracy: 0.9995: 2s - loss: 0.0021 - accuracy: 0.99 - ETA: 2s - loss: 0.0 - ETA: 2s - loss: 0.0018 - accuracy: 0. - ETA: 2s - loss: 0.0018 - accuracy:  - ETA: 1s - loss: 0 - ETA: 1s - loss: 0.0016 - accuracy: 0. - ETA: 1s - loss: 0.001 - ETA: 0s - loss: 0.0015 - accuracy: 0.99 - ETA: 0s - loss: 0.0015 - accuracy:  - ETA: 0s - loss: 0.0016
# [0.0015664033126085997, 0.9995145201683044]

# %%
ann_y_pred = loaded_model.predict(x_test).round().astype('int')

print('Accuracy: ')
print(accuracy_score(y_test, ann_y_pred))
print('Precision: ')
print(precision_score(y_test, ann_y_pred))
print('Recall: ')
print(recall_score(y_test, ann_y_pred))
print('F1: ')
print(f1_score(y_test, ann_y_pred))

print("\nClassification Report for ANN: \n", classification_report(le2.inverse_transform(y_test), le2.inverse_transform(ann_y_pred)))

cf_matrix_ann = confusion_matrix(y_test, ann_y_pred)
# Out:
# Accuracy:
# 0.9995145195984704
# Precision:
# 0.9995266787876966
# Recall:
# 0.9999849670402358
# F1:
# 0.9997557703941113
#
# Classification Report for ANN:
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96       847
#            1       1.00      1.00      1.00    133041
#
#     accuracy                           1.00    133888
#    macro avg       1.00      0.96      0.98    133888
# weighted avg       1.00      1.00      1.00    133888

# %%
ax = sns.heatmap(cf_matrix_ann, annot=True, cmap='Blues', fmt='g')

ax.set_title('Confusion Matrix');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

ax.xaxis.set_ticklabels(binary)
ax.yaxis.set_ticklabels(binary)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12040/2614846299.py in <module>
#       5 ax.set_ylabel('Actual Values ');
#       6
# ----> 7 ax.xaxis.set_ticklabels(binary)
#       8 ax.yaxis.set_ticklabels(binary)
#       9
#
# NameError: name 'binary' is not defined
